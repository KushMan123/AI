# %%
# Import Dependencies
import csv
import pandas as pd
import numpy as np
from collections import defaultdict
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import json

# %%
with open('Datasets/finaldata-1.json') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'1': {'Age': '75-year-old',
#   'Sex': 'M',
#   'Symptoms': ['blackouts', 'hypertrophy', 'dizziness', 'gout'],
#   'Pre_Medication': ['ibuprofen'],
#   'Physical Examination Results': {'Pressure': '96/64 mmHg', 'Height': '3 cm'},
#   'Test': ['The ECG',
#    'cardiac output',
#    'ECG',
#    'the ventricular rate',
#    'the jugular venous pressure',
#    'Differential diagnosisOn examination',
#    'the atrial rate',
#    'blood flow return',
#    'chest X-ray'],
#   'Diagnosis': ['loss of consciousness splits into neurologicaland vascular',
#    'pallor',
#    'hypotension',
#    'ischaemic attacks',
#    'loss of consciousness',
#    'attacks',
#    'asystole',
#    'epilepsy',
#    'dizziness',
#    'loss of cardiac output usually associated withan arrhythmia',
#    'heart block',
#    'faints',
#    'vertebrobasilar insufficiency',
#    'tachy-arrhythmias',
#    'arrhythmias'],
#   'Treatment': ['a dual-chamber system pacing',
#    'The treatment',
# ...
